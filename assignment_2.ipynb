# %% [markdown]
# <a href="https://colab.research.google.com/github/hemant935/oop-labassignment-1/blob/main/assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# problem-1
class circle():
     def __init__(self,r):
          self.radius=r
     def area(self):
         return 3.14*(self.radius*self.radius)    
     def perimeter(self):
         return 2*3.14*self.radius

r=float(input("enter the radius of the circle\n"))
newcircle=circle(r)
area=newcircle.area()
perimeter=newcircle.perimeter()
print("the area of the circle is ",area)
print("the perimeter of the circle is ",perimeter)

#problem-2
class employee():
    def __init__(self,name,emp_id,branch,salary):
        self.name=name
        self.emp_id=emp_id
        self.branch=branch
        self.salary=salary
    def display(self):
        print("employee name : ",self.name)
        print("employee id : ",self.emp_id)
        print("branch :",self.branch)
        print("employee salary:",self.salary)    

names=[]
ids=[]
branches=[]
salarys=[]
details=[]
for i in range(0,5):
    name=input("enter employee name :")
    names.append(name)
    id=input("enter employee id :")
    ids.append(id)
    branch=input("enter branch :")
    branches.append(branch)
    salary=input("enter salary : ")
    salarys.append(salary)    
for i in range(0,5):  
     details.append(employee(names[i],ids[i],branches[i],salarys[i]))
     details[i].display() 
# problem-3
class account():
    def __init__(self,Account_No, Account_holder_name,Amount):
        self.number=Account_No
        self.name=Account_holder_name
        self.amount=Amount

    def account_details(self):
        print("Enter account number : ",self.number)
        print("Enter account holder name : ",self.name)
        print("Total amount remaining : ",self.amount)
    def withdraw(self,amt):
        self.amount=self.amount-amt
    def deposit(self,amt):
        self.amount=self.amount+amt
    def check_balance(self):
        print("Account Balance : ",self.amount)        

person=account(2300,"hemant",50000)
person.account_details()
person.withdraw(2000)
person.check_balance()
person.deposit(1000)
person.check_balance()

# PROBLEM-4
class students_details():
    def __init__(self,student_name,USN,marks):
        self.name=student_name
        self.usn=USN
        self.marks=marks
    def display_name(self):
        print("student name : ",self.name)    
    def display_usn(self):
        print("USN : ",self.usn)
    def display_marks(self):
        print("Marks : ",self.marks)
marks=[90,95,98] #marks in three subjects       
student1=students_details('hemant',58,marks)                    
student1.display_name()
student1.display_usn()        
student1.display_marks()

# problem-5
genaral_ward=0
oxygen_support=0
class covid19_patient_details():
    Name=None
    symtoms=[]
    doa=0
    o2level=0
    dod=0
    def entry(self):
        self.Name=input("Enter patient Name : ")
        self.doa=input("Enter the date of admission : ")
        print("Enter symtoms : ")
        for i in range(0,3): 
           sy=input()           
           self.symtoms.append(sy)
        self.o2level=int(input("Enter the oxygen level : "))
        self.dod=input("Enter Date of Discharge : ")
    def severity(self):
            global genaral_ward
            global oxygen_support
            if self.o2level < 90:
             oxygen_support=oxygen_support+1
            else:
             genaral_ward=genaral_ward+1

    def display(self):
        global genaral_ward
        global oxygen_support
        print("Number of patients in General ward : ",genaral_ward)
        print("Number of patients needed oxygen support : ",oxygen_support)
        total_patient=oxygen_support+genaral_ward
        print("Total number of patients : ",total_patient)        
patient1=covid19_patient_details()
patient1.entry()
patient1.severity()
# patient1.display()

patient2=covid19_patient_details()
patient2.entry()
patient2.severity()
# patient2.display()

patient3=covid19_patient_details()
patient3.entry()
patient3.severity()

patient3.display()

#  problem-6 

class time():
  def __init__(self,hour=0,min=0,sec=0):
     self.hour=hour
     self.minute=min
     self.second=sec
  def display(self):
    print(self.hour,":",self.minute,":",self.second)

t1=time(0,0,0)
t1.display()
t1.hour=12
t1.minute=30
t1.second=50
t1.display()

# problem-7

class Student:
  def __init__(self, name, age, roll):
    self.name = name
    self.age = age
    self.roll = roll

def compare(Std1, Std2):
  if Std1.age == Std2.age:
    print("Their ages are equal.")
  else:
    print("Their ages are not equal.")
    
Std1 = Student('Rahul', 21, 33)
Std2 = Student ('Rohit', 22, 74)
compare(Std1, Std2)

# problem -8
class student_details():
  sem="third"
  Institute="IIIT DHARWAD"
  def __init__(self,name,usn):
    self.name=name
    self.usn=usn

  @classmethod
  def display(cls):
    print(cls.sem)
    print(cls.Institute)  
    
  def Display(self):
    print(self.name)
    print(self.usn)

  @staticmethod
  def printclass(name, usn, sem, Institute):
    print("Name: ",name)
    print("USN: ", usn)
    print("semester: ",sem)
    print("Institute: ",Institute)  

s1=student_details("Hemant",58)
s1.display()
s1.Display()
s1.printclass("Hemant",58,"third","IIIT DHARWAD")

#problem-9
class student():
  def __init__(self,Name,Roll,Sem,CPU,RAM,Hard_disk,display_details):
    self.Name = Name
    self.Roll = Roll
    self.Sem = Sem

    self.lap = self.laptop(CPU,RAM,Hard_disk,display_details)
  class laptop():
    def __init__(self,CPU,RAM,Hard_disk,display_details):
      self.CPU = CPU
      self.RAM = RAM
      self.Hard_disk = Hard_disk
      self.display_details = display_details
    def displayDetails(self):
      print("CPU : ",self.CPU)
      print("RAM: ",self.RAM)
      print("Hard_disk: ",self.Hard_disk)
      print("Display details: ",self.display_details)
  def display_student(self):
    print("Name: ",self.Name)
    print("Roll: ",self.Roll)
    print("Sem: ",self.Sem)
    self.lap.displayDetails()

s1 = student("Halua",23,3,"i7","8 GB","1TB HDD","8K")
s2 = student("Balton",24,5,"i9","16 GB","1TB SSD","16K")
s3 = student("Sheldon",45,1,"i3","4 GB","256GB HDD","2K")
s1.lap.displayDetails()
s1.display_student()
s2.lap.displayDetails()
s2.display_student()

s3.lap.displayDetails()
s3.display_student()
